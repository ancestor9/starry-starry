# %% [markdown]
# # Structured data classification from scratch
# - https://keras.io/examples/structured_data/structured_data_classification_from_scratch/

# %%
from IPython.core.interactiveshell import InteractiveShell # 모든 명령어 출력
InteractiveShell.ast_node_interactivity = 'all'
from IPython.core.display import display, HTML # 화면 좌우 크기 100%
display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings # 파이썬 버전에 따른 오류 출력 방지
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pylab as plt
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from IPython.display import Image
width = 800; height = 600
dir_path = r'D:\aSSIST\introduction_to_ml_with_python-master\aSSIST_20220111_1학기'

# %%
Image(filename= dir_path + '/슬라이드259.jpg', width=width, height=height)

# %%
Image(filename= dir_path + '/슬라이드260.jpg', width=width, height=height)

# %%
Image(filename= dir_path + '/슬라이드261.jpg', width=width, height=height)

# %%
Image(filename= dir_path + '/슬라이드262.jpg', width=width, height=height)

# %% [markdown]
# # 로지스틱회귀분석과 perceptron

# %%
from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)

# %%
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X, y)

clf.score(X, y)
# Out:
# Perceptron()
# 0.9393433500278241

# %%
def guess(clf):
    clf.fit(X, y)
    return clf.score(X, y)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
guess(clf)
# Out:
# 0.6720458216576347

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron()
clf.fit(X,y)


#guess(clf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-2c321cdbd87e> in <module>
#       1 from sklearn.linear_model import Perceptron
#       2 clf = Perceptron()
# ----> 3 clf.fit(X,y)
#       4
#       5
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
#     723             Returns an instance of self.
#     724         """
# --> 725         return self._fit(X, y, alpha=self.alpha, C=1.0,
#     726                          loss=self.loss, learning_rate=self.learning_rate,
#     727                          coef_init=coef_init, intercept_init=intercept_init,
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_stochastic_gradient.py in _fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
# ...

# %%
clf.score(X, y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(random_state=1, hidden_layer_sizes=(10, 12), max_iter=300).fit(X_train, y_train)
clf.predict_proba(X_test[:1])

clf.predict(X_test[:5, :])

clf.score(X_test, y_test)
# Out:
# array([[0.16352345, 0.83647655]])
# array([1, 0, 1, 0, 1])
# 0.72

# %%
clf = MLPClassifier(random_state=1,
                    solver='sgd',
                    hidden_layer_sizes=(15, 2), 
                    max_iter=300).fit(X_train, y_train)
clf.predict_proba(X_test[:1])

clf.predict(X_test[:5, :])

clf.score(X_test, y_test)
# Out:
# array([[0.31914663, 0.68085337]])
# array([1, 0, 1, 1, 1])
# 0.72

# %%
from nltk.corpus import wordnet

# %%
wordnet.synsets('car')
# Out:
# [Synset('car.n.01'),
#  Synset('car.n.02'),
#  Synset('car.n.03'),
#  Synset('car.n.04'),
#  Synset('cable_car.n.01')]

# %%
from sklearn.datasets import load_digits
from sklearn.linear_model import Perceptron
X, y = load_digits(return_X_y=True)
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X, y)

clf.score(X, y)
# Out:
# Perceptron()
# 0.9393433500278241

# %% [markdown]
# https://scikit-learn.org/stable/modules/neural_networks_supervised.html
# <img src='https://scikit-learn.org/stable/_images/multilayerperceptron_network.png' width=500 height=400>

# %%
from sklearn.datasets import load_digits
from PIL import Image
load_digits()
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
np.float16(1e-4)
np.float16(1e-8)
# Out:
# 0.0001
# 0.0

# %%
np.float32(1e-8)
np.float32(1e-100)
# Out:
# 1e-08
# 0.0

# %% [markdown]
# https://onevision.tistory.com/entry/Optimizer-%EC%9D%98-%EC%A2%85%EB%A5%98%EC%99%80-%ED%8A%B9%EC%84%B1-Momentum-RMSProp-Adam
#
# <img src='https://img1.daumcdn.net/thumb/R720x0.q80/?scode=mtistory2&fname=http%3A%2F%2Fcfile23.uf.tistory.com%2Fimage%2F996A04425AB85ED0260F3E'>

# %%
x = np.array([-1,1,2])
np.array(x>0, dtype=np.int)

np.exp(1000)

a = np.array([10, 14,15])
np.exp(a)/np.sum(np.exp(a))

c = np.max(a)
c
a-c

np.exp(a-c)/np.sum(np.exp(a-c))
# Out:
# array([0, 1, 1])
# inf
# array([0.00490169, 0.26762315, 0.72747516])
# 15
# array([-5, -1,  0])
# array([0.00490169, 0.26762315, 0.72747516])

# %%
np.exp(c-a)/np.sum(np.exp(c-a))
# Out:
# array([0.97555875, 0.01786798, 0.00657326])

# %%
np.exp(6)/np.exp(7)
np.exp(-6)/np.exp(-7)
# Out:
# 0.36787944117144233
# 2.718281828459045

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

# %%
np.random.seed(5)

# %%
class LossHistory(keras.callbacks.Callback):
    def init(self):
        self.losses =[]
        
    def on_epoch_end(self, batch, log={}):
        self.losses.append(log.get('loss'))

# %%
# 코드 사전 정의
code2idx ={'c4':0, 'd4':1, 'e4':2, 'f4':3, 'g4':4, 'a4':5, 'b4':6,
           'c8':7, 'd8':8, 'e8':9, 'f8':10, 'g8':11, 'a8':12, 'b8':13
          }
idx2code = {v: k for k, v in code2idx.items()}

# %%
# 시퀀스데이터 정의
seq='g8,e8,e4,f8,d8,d4,c8,d8,e8,f8,g8,g8,g4,g8,e8,e8,e8,f8,d8,d4,c8,e8,g8,g8,e8,e8,e4,d8,d8,d8,d8,d8,e8,f4,e8,e8,e8,e8,e8,f8,g4,g8,e8,e4,f8,d8,d4,c8,e8,g8,g8,e8,e8,e4'
seq = list(seq.split(','))

# %%
def seq2dataset(seg, window_size):
    dataset =[]
    for i in range(len(seq)-window_size):
        subset=seq[i:(i+window_size+1)]
        dataset.append([code2idx[item] for item in subset])
    return np.array(dataset)

# %%
# 데이터셋 생성하기
dataset = seq2dataset(seq, window_size = 4)
dataset[:10]
dataset.shape
# Out:
# array([[11,  9,  2, 10,  8],
#        [ 9,  2, 10,  8,  1],
#        [ 2, 10,  8,  1,  7],
#        [10,  8,  1,  7,  8],
#        [ 8,  1,  7,  8,  9],
#        [ 1,  7,  8,  9, 10],
#        [ 7,  8,  9, 10, 11],
#        [ 8,  9, 10, 11, 11],
#        [ 9, 10, 11, 11,  4],
#        [10, 11, 11,  4, 11]])
# (50, 5)

# %%
# 입력고 출력 변수 분리하기
x_train = dataset[:, 0:4]
y_train = dataset[:, 4]
x_train[:10]
y_train[:10]
# Out:
# array([[11,  9,  2, 10],
#        [ 9,  2, 10,  8],
#        [ 2, 10,  8,  1],
#        [10,  8,  1,  7],
#        [ 8,  1,  7,  8],
#        [ 1,  7,  8,  9],
#        [ 7,  8,  9, 10],
#        [ 8,  9, 10, 11],
#        [ 9, 10, 11, 11],
#        [10, 11, 11,  4]])
# array([ 8,  1,  7,  8,  9, 10, 11, 11,  4, 11])

# %%
max_idx_value =13

# %%
import matplotlib.pyplot as plt

# %%
#import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
(x_train,y_train), (x_test, y_test) = mnist.load_data()

x_val = x_train[50000:] 
y_val = y_train[50000:]
x_train = x_train[:50000]
y_train = y_train[:50000]

# %%
x_train = x_train.reshape(50000, 28*28).astype('float32')/255.0
x_val = x_val.reshape(10000, 28*28).astype('float32')/255.0
x_test = x_test.reshape(10000, 28*28).astype('float32')/255.0

# %%
np.random.choice(50000, 10000).shape
# Out:
# (10000,)

# %%
train_rand_index = np.random.choice(50000, 10000)
val_rand_index = np.random.choice(10000, 2000)

x_train = x_train[train_rand_index]
y_train = y_train[train_rand_index]
x_val = x_val[val_rand_index]
y_val = y_val[val_rand_index]

# %%
x_train.shape
# Out:
# (10000, 784)

# %%
y_train = np_utils.to_categorical(y_train)
y_val = np_utils.to_categorical(y_val)
y_test = np_utils.to_categorical(y_test)

# %%
model = keras.Sequential([
    # the hidden ReLU layers
    layers.Dense(units=2, activation='relu', input_shape=[28*28]),
    layers.Dense(units=10, activation='softmax'),
    # the linear output layer 
    #layers.Dense(units=1),
])

# %%
model.compile(optimizer=keras.optimizers.SGD(),
              loss=keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %%
model = keras.Sequential()
model.add(Dense(units=32, input_dim=28*28, activation='relu'))
model.add(Dense(units=10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping()
hist = model.fit(x_train, y_train, epochs=200, batch_size=32, validation_data=(x_val, y_val),
                #callbacks= [early_stopping]
                )
# Out:
# Epoch 1/200
# 313/313 [==============================] - 1s 3ms/step - loss: 2.2202 - accuracy: 0.1553 - val_loss: 2.0979 - val_accuracy: 0.1595
# Epoch 2/200
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9424 - accuracy: 0.2408 - val_loss: 1.8111 - val_accuracy: 0.2720
# Epoch 3/200
# 313/313 [==============================] - 1s 2ms/step - loss: 1.7274 - accuracy: 0.3084 - val_loss: 1.6517 - val_accuracy: 0.3380
# Epoch 4/200
# 313/313 [==============================] - 1s 2ms/step - loss: 1.6200 - accuracy: 0.3220 - val_loss: 1.5798 - val_accuracy: 0.3405
# Epoch 5/200
# 313/313 [==============================] - 1s 2ms/step - loss: 1.5610 - accuracy: 0.3378 - val_loss: 1.5374 - val_accuracy: 0.3660
# Epoch 6/200
# 313/313 [==============================] - 1s 3ms/step - loss: 1.5210 - accuracy: 0.3607 - val_loss: 1.5046 - val_accuracy: 0.3900
# Epoch 7/200
# ...

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
fig, loss_ax = plt.subplots()
acc_ac = loss_ax.twinx()
acc_ac.plot(hist.history['loss'], 'y', label='train loss')
acc_ac.plot(hist.history['val_loss'], 'r', label='val loss')
acc_ac.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ac.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('accuracy')
acc_ac.set_ylabel('loss')

loss_ax.legend(loc='upper left')
acc_ac.legend(loc='lower left')
# Out:
# Text(0.5, 0, 'epoch')
# Text(0, 0.5, 'accuracy')
# Text(0, 0.5, 'loss')
# No handles with labels found to put in legend.

# %%
loss_ax.twinx

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(64, input_shape=(28*28,)))
# Afterwards, we do automatic shape inference:
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.categorical_crossentropy,
              metrics=[keras.metrics.categorical_accuracy,
                      ])

# %%
model.fit(x_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 22/22 [==============================] - 1s 3ms/step - loss: 0.3280 - categorical_accuracy: 0.9200
# Epoch 2/5
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2478 - categorical_accuracy: 0.9486
# Epoch 3/5
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2072 - categorical_accuracy: 0.9643
# Epoch 4/5
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1687 - categorical_accuracy: 0.9729
# Epoch 5/5
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1426 - categorical_accuracy: 0.9757

# %%
model.fit(x_train, y_train)
# Out:
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1244 - categorical_accuracy: 0.9857

# %%
28*28*64 +64
64*10+10
# Out:
# 50240
# 650

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                650
# ...
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13320/2110231839.py in <module>
# ----> 1 SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
#
# AttributeError: 'NoneType' object has no attribute 'create'

# %% [markdown]
# # Study 1

# %%
file_url = "http://storage.googleapis.com/download.tensorflow.org/data/heart.csv"
dataframe = pd.read_csv(file_url)

dataframe.shape

dataframe
# Out:
# (303, 14)
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   52    1   1       118   186    0        2      190      0      0.0
# 299   43    0   4       132   341    1        2      136      1      3.0
# 300   65    1   4       135   254    0        2      127      0      2.8
# 301   48    1   4       130   256    1        2      150      1      0.0
# 302   63    0   4       150   407    0        2      154      0      4.0
#
#      slope  ca        thal  target
# 0        3   0       fixed       0
# ...

# %%
dataframe.target.value_counts(normalize=True)
dataframe.target.value_counts()
# Out:
# 0    0.726073
# 1    0.273927
# Name: target, dtype: float64
# 0    220
# 1     83
# Name: target, dtype: int64

# %%
val_dataframe = dataframe.sample(frac=0.2, random_state=1337)
train_dataframe = dataframe.drop(val_dataframe.index)

print(
    "Using %d samples for training and %d for validation"
    % (len(train_dataframe), len(val_dataframe))
)
# Out:
# Using 242 samples for training and 61 for validation

# %%
val_dataframe
dataframe.drop(val_dataframe.index)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 96    41    1   3       112   250    0        0      179      0      0.0
# 142   67    1   4       100   299    0        2      125      1      0.9
# 80    51    1   3        94   227    0        0      154      1      0.0
# 67    41    1   2       135   203    0        0      132      0      0.0
# 188   41    0   2       126   306    0        0      163      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 140   62    0   4       138   294    1        0      106      0      1.9
# 258   51    1   3       110   175    0        0      123      0      0.6
# 269   41    1   4       110   172    0        2      158      0      0.0
# 85    70    1   4       145   174    0        0      125      1      2.6
# 153   58    1   4       128   259    0        2      130      1      3.0
#
#      slope  ca        thal  target
# 96       1   0      normal       0
# ...

# %%
labels = dataframe.pop("target")
tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
# Out:
# <TensorSliceDataset element_spec=({'age': TensorSpec(shape=(), dtype=tf.int64, name=None), 'sex': TensorSpec(shape=(), dtype=tf.int64, name=None), 'cp': TensorSpec(shape=(), dtype=tf.int64, name=None), 'trestbps': TensorSpec(shape=(), dtype=tf.int64, name=None), 'chol': TensorSpec(shape=(), dtype=tf.int64, name=None), 'fbs': TensorSpec(shape=(), dtype=tf.int64, name=None), 'restecg': TensorSpec(shape=(), dtype=tf.int64, name=None), 'thalach': TensorSpec(shape=(), dtype=tf.int64, name=None), 'exang': TensorSpec(shape=(), dtype=tf.int64, name=None), 'oldpeak': TensorSpec(shape=(), dtype=tf.float64, name=None), 'slope': TensorSpec(shape=(), dtype=tf.int64, name=None), 'ca': TensorSpec(shape=(), dtype=tf.int64, name=None), 'thal': TensorSpec(shape=(), dtype=tf.string, name=None)}, TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
# tf.data.Dataset.from_tensor_slices?

# %% [markdown]
# Signature: tf.data.Dataset.from_tensor_slices(tensors, name=None)
# Docstring:
# Creates a `Dataset` whose elements are slices of the given tensors.
#
# The given tensors are sliced along their first dimension. This operation
# preserves the structure of the input tensors, removing the first dimension
# of each tensor and using it as the dataset dimension. All input tensors
# must have the same size in their first dimensions.

# %%
# Slicing a 1D tensor produces scalar tensor elements.
dataset = tf.data.Dataset.from_tensor_slices([1, 2, 3])
dataset
list(dataset.as_numpy_iterator())
# Out:
# <TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>
# [1, 2, 3]

# %%
# Slicing a 2D tensor produces 1D tensor elements.
dataset = tf.data.Dataset.from_tensor_slices([[1, 2], [3, 4]])
list(dataset.as_numpy_iterator())
pd.DataFrame(list(dataset.as_numpy_iterator()))
# Out:
# [array([1, 2]), array([3, 4])]
#    0  1
# 0  1  2
# 1  3  4

# %%
# Slicing a tuple of 1D tensors produces tuple elements containing
# scalar tensors.
dataset = tf.data.Dataset.from_tensor_slices(([1, 2], [3, 4], [5, 6]))
list(dataset.as_numpy_iterator())
pd.DataFrame(list(dataset.as_numpy_iterator()))
# Out:
# [(1, 3, 5), (2, 4, 6)]
#    0  1  2
# 0  1  3  5
# 1  2  4  6

# %%
# Dictionary structure is also preserved.
dataset = tf.data.Dataset.from_tensor_slices({"a": [1, 2], "b": [3, 4]})
list(dataset.as_numpy_iterator()) == [{'a': 1, 'b': 3},
                                      {'a': 2, 'b': 4}]
pd.DataFrame(list(dataset.as_numpy_iterator()))
# Out:
# True
#    a  b
# 0  1  3
# 1  2  4

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds


train_ds = dataframe_to_dataset(train_dataframe)
val_ds = dataframe_to_dataset(val_dataframe)

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=57>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=4>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=140>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=241>, 'fbs': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'restecg': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'thalach': <tf.Tensor: shape=(), dtype=int64, numpy=123>, 'exang': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'oldpeak': <tf.Tensor: shape=(), dtype=float64, numpy=0.2>, 'slope': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'ca': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'thal': <tf.Tensor: shape=(), dtype=string, numpy=b'reversible'>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %%
from tensorflow.keras.layers import IntegerLookup
from tensorflow.keras.layers import Normalization
from tensorflow.keras.layers import StringLookup


def encode_numerical_feature(feature, name, dataset):
    # Create a Normalization layer for our feature
    normalizer = Normalization()

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    encoded_feature = normalizer(feature)
    return encoded_feature


def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = StringLookup if is_string else IntegerLookup
    # Create a lookup layer which will turn strings into integer indices
    lookup = lookup_class(output_mode="binary")

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the set of possible string values and assign them a fixed integer index
    lookup.adapt(feature_ds)

    # Turn the string input into integer indices
    encoded_feature = lookup(feature)
    return encoded_feature

# %%
import csv
import numpy as np

Get the real data from https://www.kaggle.com/mlg-ulb/creditcardfraud/

fname = "/Users/fchollet/Downloads/creditcard.csv"

all_features = []
all_targets = []
with open(fname) as f:
    for i, line in enumerate(f):
        if i == 0:
            print("HEADER:", line.strip())
            continue  # Skip header
        fields = line.strip().split(",")
        all_features.append([float(v.replace('"', "")) for v in fields[:-1]])
        all_targets.append([int(fields[-1].replace('"', ""))])
        if i == 1:
            print("EXAMPLE FEATURES:", all_features[-1])

features = np.array(all_features, dtype="float32")
targets = np.array(all_targets, dtype="uint8")
print("features.shape:", features.shape)
print("targets.shape:", targets.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-431862b8890e> in <module>
#       7 all_features = []
#       8 all_targets = []
# ----> 9 with open(fname) as f:
#      10     for i, line in enumerate(f):
#      11         if i == 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/fchollet/Downloads/creditcard.csv'
